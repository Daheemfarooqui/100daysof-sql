# %% [markdown]
# # SQL Practice - Day 8
#
# ## CASE WHEN (Intermediate)
#
# 10 interview practice questions.

# %% [markdown]
# ## Q1
#
# **Task:** Create employee grades: A (>=90000), B (70000-89999), C (<70000).

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4],'salary':[95000,82000,65000,72000]})
df
# Out:
#    emp_id  salary
# 0       1   95000
# 1       2   82000
# 2       3   65000
# 3       4   72000

# %%
import pandasql
from pandasql import sqldf

sqldf("""
select emp_id ,salary,
        case
            when salary >= 90000 then "A"
            when salary >= 70000 and salary  <=89999 then "B"
            else "C"
        end as "grade"
from df



""")
# Out:
#    emp_id  salary grade
# 0       1   95000     A
# 1       2   82000     B
# 2       3   65000     C
# 3       4   72000     B

# %% [markdown]
# ## Q2
#
# **Task:** Count male and female employees using CASE + SUM().

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4,5],'gender':['M','F','M','F','M']})
df
# Out:
#    emp_id gender
# 0       1      M
# 1       2      F
# 2       3      M
# 3       4      F
# 4       5      M

# %%
sqldf("""

SELECT
    SUM(CASE WHEN gender = 'M' THEN 1 ELSE 0 END) AS male_count,
    SUM(CASE WHEN gender = 'F' THEN 1 ELSE 0 END) AS female_count
FROM df;
""")
# Out:
#    male_count  female_count
# 0           3             2

# %% [markdown]
# ## Q3
#
# **Task:** Calculate total sales for Online and Offline channels separately.

# %%
import pandas as pd
df=pd.DataFrame({'channel':['Online','Offline','Online','Offline'],'amount':[1000,800,1200,900]})
df
# Out:
#    channel  amount
# 0   Online    1000
# 1  Offline     800
# 2   Online    1200
# 3  Offline     900

# %%
sqldf("""
SELECT 
SUM(CASE WHEN CHANNEL = 'Online' THEN AMOUNT ELSE  0  END ) AS ONLINE_CAT,
SUM(CASE WHEN CHANNEL = 'Offline' THEN AMOUNT ELSE 0 END ) AS OFFLINE
FROM df


""")
# Out:
#    ONLINE_CAT  OFFLINE
# 0        2200     1700

# %% [markdown]
# ## Q4
#
# **Task:** Find average salary of HR and Non-HR employees using CASE.

# %%
import pandas as pd
df=pd.DataFrame({'department':['HR','HR','IT','Sales'],'salary':[50000,60000,70000,80000]})
df
# Out:
#   department  salary
# 0         HR   50000
# 1         HR   60000
# 2         IT   70000
# 3      Sales   80000

# %%
sqldf("""
SELECT 
AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 END) AS AVG_HR_SALARY,
AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 END) AS NON_HR_SALARY
FROM df


""")
# Out:
#    AVG_HR_SALARY  NON_HR_SALARY
# 0        27500.0        37500.0

# %% [markdown]
# ## Q5
#
# **Task:** Label loans as Risky, Safe and Unknown.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'loan_id':[1,2,3,4],'amount':[50000,150000,np.nan,80000]})
df
# Out:
#    loan_id    amount
# 0        1   50000.0
# 1        2  150000.0
# 2        3       NaN
# 3        4   80000.0

# %%
sqldf("""
select 
loan_id ,
amount,
case
    when amount > 100000 then "Risky"
    when amount >= 50000 then "safe"
    else "unknown"
end as lable
from df


""")
# Out:
#    loan_id    amount    lable
# 0        1   50000.0     safe
# 1        2  150000.0    Risky
# 2        3       NaN  unknown
# 3        4   80000.0     safe

# %% [markdown]
# ## Q6
#
# **Task:** Using GROUP BY + CASE, count Premium (>=1000) and Regular orders.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,102,103],'amount':[500,1500,1200,300,2500]})
df
# Out:
#    customer_id  amount
# 0          101     500
# 1          101    1500
# 2          102    1200
# 3          102     300
# 4          103    2500

# %%
sqldf("""
    select 
    customer_id ,amount,
    case when amount >= 1000 then "Premium"
    else "Regular"
    end as "TYpe"
    from df
    group by customer_id 


""")
# Out:
#    customer_id  amount     TYpe
# 0          101     500  Regular
# 1          102    1200  Premium
# 2          103    2500  Premium

# %% [markdown]
# ## Q7
#
# **Task:** Sort departments: HR first, IT second, Others last using CASE in ORDER BY.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D'],'department':['Sales','IT','HR','Finance']})
df
# Out:
#   name department
# 0    A      Sales
# 1    B         IT
# 2    C         HR
# 3    D    Finance

# %%
sqldf("""
select department ,
    case 
        when department = "HR" then 1
         when department = 'IT' then 2
    else 3
    end as sortedby
    from df 
    order by sortedby




""")
# Out:
#   department  sortedby
# 0         HR         1
# 1         IT         2
# 2      Sales         3
# 3    Finance         3

# %% [markdown]
# ## Q8
#
# **Task:** Create order status: High, Medium, Low.

# %%
import pandas as pd
df=pd.DataFrame({'order_id':[1,2,3,4],'amount':[250,700,1000,1800]})
df
# Out:
#    order_id  amount
# 0         1     250
# 1         2     700
# 2         3    1000
# 3         4    1800

# %%
sqldf("""
select order_id , amount,
case
    when amount >=1000 then "high"
    when amount >= 500 then "Medium"
    else "low"
end as "Order_status"
from df


""")
# Out:
#    order_id  amount Order_status
# 0         1     250          low
# 1         2     700       Medium
# 2         3    1000         high
# 3         4    1800         high

# %% [markdown]
# ## Q9
#
# **Task:** Calculate bonus: Sales=10%, IT=8%, Others=5%.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D'],'department':['Sales','IT','HR','Sales'],'salary':[50000,60000,70000,80000]})
df
# Out:
#   name department  salary
# 0    A      Sales   50000
# 1    B         IT   60000
# 2    C         HR   70000
# 3    D      Sales   80000

# %%
sqldf("""
select name , department , salary,
case 
    when department ='Sales' then  salary *0.10
    when department = 'IT' then salary *0.08
    else salary*0.05
end as "bonus"
from df
""")
# Out:
#   name department  salary   bonus
# 0    A      Sales   50000  5000.0
# 1    B         IT   60000  4800.0
# 2    C         HR   70000  3500.0
# 3    D      Sales   80000  8000.0

# %% [markdown]
# ## Q10
#
# **Task:** Count employees earning >=60000 and <60000 using CASE + COUNT().

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4,5],'salary':[45000,60000,75000,55000,90000]})
df
# Out:
#    emp_id  salary
# 0       1   45000
# 1       2   60000
# 2       3   75000
# 3       4   55000
# 4       5   90000

# %%
sqldf("""
select 
sum(case when salary >= 60000 then 1 else 0 end)as "high_salar",
sum(case when salary < 60000 then 1 else 0 end ) as "medium salary"
from df


""")
# Out:
#    high_salar  medium salary
# 0           3              2
