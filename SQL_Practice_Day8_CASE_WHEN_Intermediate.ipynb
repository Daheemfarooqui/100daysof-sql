# %% [markdown]
# # SQL Practice - Day 8
#
# ## CASE WHEN (Intermediate)
#
# 10 interview practice questions.

# %% [markdown]
# ## Q1
#
# **Task:** Create employee grades: A (>=90000), B (70000-89999), C (<70000).

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4],'salary':[95000,82000,65000,72000]})
df
# Out:
#    emp_id  salary
# 0       1   95000
# 1       2   82000
# 2       3   65000
# 3       4   72000

# %%
import pandasql
from pandasql import sqldf

sqldf("""
select emp_id ,salary,
        case
            when salary >= 90000 then "A"
            when salary >= 70000 and salary  <=89999 then "B"
            else "C"
        end as "grade"
from df



""")
# Out:
#    emp_id  salary grade
# 0       1   95000     A
# 1       2   82000     B
# 2       3   65000     C
# 3       4   72000     B

# %% [markdown]
# ## Q2
#
# **Task:** Count male and female employees using CASE + SUM().

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4,5],'gender':['M','F','M','F','M']})
df
# Out:
#    emp_id gender
# 0       1      M
# 1       2      F
# 2       3      M
# 3       4      F
# 4       5      M

# %%
sqldf("""

SELECT
    SUM(CASE WHEN gender = 'M' THEN 1 ELSE 0 END) AS male_count,
    SUM(CASE WHEN gender = 'F' THEN 1 ELSE 0 END) AS female_count
FROM df;
""")
# Out:
#    male_count  female_count
# 0           3             2

# %% [markdown]
# ## Q3
#
# **Task:** Calculate total sales for Online and Offline channels separately.

# %%
import pandas as pd
df=pd.DataFrame({'channel':['Online','Offline','Online','Offline'],'amount':[1000,800,1200,900]})
df
# Out:
#    channel  amount
# 0   Online    1000
# 1  Offline     800
# 2   Online    1200
# 3  Offline     900

# %%
sqldf("""
SELECT 
SUM(CASE WHEN CHANNEL = 'Online' THEN AMOUNT ELSE  0  END ) AS ONLINE_CAT,
SUM(CASE WHEN CHANNEL = 'Offline' THEN AMOUNT ELSE 0 END ) AS OFFLINE
FROM df


""")
# Out:
#    ONLINE_CAT  OFFLINE
# 0        2200     1700

# %% [markdown]
# ## Q4
#
# **Task:** Find average salary of HR and Non-HR employees using CASE.

# %%
import pandas as pd
df=pd.DataFrame({'department':['HR','HR','IT','Sales'],'salary':[50000,60000,70000,80000]})
df
# Out:
#   department  salary
# 0         HR   50000
# 1         HR   60000
# 2         IT   70000
# 3      Sales   80000

# %%
sqldf("""
SELECT 
AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 ) END AVG_HR_SALARY,
AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 ) END NON_HR_SALARY
FROM df


""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: near ")": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near ")": syntax error
# [SQL:
# SELECT
# AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 ) END AVG_HR_SALARY,
# AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 ) END NON_HR_SALARY
# FROM df
#
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sqldf("""
#       2 SELECT
#       3 AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 ) END AVG_HR_SALARY,
#       4 AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 ) END NON_HR_SALARY
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandasql\sqldf.py:156, in sqldf(query, env, db_uri)
#     124 def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     125     """
#     126     Query pandas data frames using sql syntax
#     127     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)    154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandasql\sqldf.py:61, in PandaSQL.__call__(self, query, env)
#      58     write_table(env[table_name], table_name, conn)
#      60 try:
# ---> 61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
#      63     raise PandaSQLException(ex)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:730, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     720     return pandas_sql.read_table(
#     721         sql,
#     722         index_col=index_col,
#    (...)    727         dtype_backend=dtype_backend,
#     728     )
#     729 else:
# --> 730     return pandas_sql.read_query(
#     731         sql,
#     732         index_col=index_col,
#     733         params=params,
#     734         coerce_float=coerce_float,
#     735         parse_dates=parse_dates,
#     736         chunksize=chunksize,
#     737         dtype_backend=dtype_backend,
#     738         dtype=dtype,
#     739     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1856, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1801 def read_query(
#    1802     self,
#    1803     sql: str,
#    (...)   1810     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1811 ) -> DataFrame | Iterator[DataFrame]:
#    1812     """
#    1813     Read SQL query into a DataFrame.
#    1814
#    (...)   1854
#    1855     """
# -> 1856     result = self.execute(sql, params)
#    1857     columns = result.keys()
#    1859     if chunksize is not None:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
# AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 ) END AVG_HR_SALARY,
# AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 ) END NON_HR_SALARY
# FROM df
#
#
# ': (sqlite3.OperationalError) near ")": syntax error
# [SQL:
# SELECT
# AVG(CASE WHEN DEPARTMENT = "HR" THEN SALARY ELSE 0 ) END AVG_HR_SALARY,
# AVG(CASE WHEN DEPARTMENT != "HR" THEN SALARY ELSE 0 ) END NON_HR_SALARY
# FROM df
#
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Q5
#
# **Task:** Label loans as Risky, Safe and Unknown.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'loan_id':[1,2,3,4],'amount':[50000,150000,np.nan,80000]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q6
#
# **Task:** Using GROUP BY + CASE, count Premium (>=1000) and Regular orders.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,102,103],'amount':[500,1500,1200,300,2500]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q7
#
# **Task:** Sort departments: HR first, IT second, Others last using CASE in ORDER BY.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D'],'department':['Sales','IT','HR','Finance']})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q8
#
# **Task:** Create order status: High, Medium, Low.

# %%
import pandas as pd
df=pd.DataFrame({'order_id':[1,2,3,4],'amount':[250,700,1000,1800]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q9
#
# **Task:** Calculate bonus: Sales=10%, IT=8%, Others=5%.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D'],'department':['Sales','IT','HR','Sales'],'salary':[50000,60000,70000,80000]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q10
#
# **Task:** Count employees earning >=60000 and <60000 using CASE + COUNT().

# %%
import pandas as pd
df=pd.DataFrame({'emp_id':[1,2,3,4,5],'salary':[45000,60000,75000,55000,90000]})
df

# %%
# Write your SQL here
