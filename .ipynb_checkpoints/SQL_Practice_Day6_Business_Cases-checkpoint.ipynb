# %% [markdown]
# # SQL Practice - Day 6
#
# ## Business Case SQL Questions (Basic)
#
# 15 interview-style business SQL problems.

# %% [markdown]
# ## Q1
#
# **Business Case:** Find the top 5 customers by total spending.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,103,104,105,106],'amount':[100,300,500,700,600,400,800]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q2
#
# **Business Case:** Find customers who placed more than one order.

# %%
import pandas as pd
df=pd.DataFrame({'order_id':[1,2,3,4,5,6],'customer_id':[101,101,102,103,103,103]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q3
#
# **Business Case:** Find the department with the highest average salary.

# %%
import pandas as pd
df=pd.DataFrame({'department':['HR','HR','IT','IT','Sales','Sales'],'salary':[50000,60000,80000,70000,90000,85000]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q4
#
# **Business Case:** Find products that have never been ordered.

# %%
import pandas as pd
df=pd.DataFrame({'product_id':[1,2,3,4],'product_name':['A','B','C','D']})
df1=pd.DataFrame({'order_id':[1,2,3],'product_id':[1,3,3]})
print(df)
print(df1)

# %%
# Write your SQL here

# %% [markdown]
# ## Q5
#
# **Business Case:** Find customers whose spending is above the average customer spending.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,103,104],'amount':[100,400,500,700,300]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q6
#
# **Business Case:** Find the second highest salary in each department.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D','E','F'],'department':['HR','HR','HR','IT','IT','IT'],'salary':[50000,60000,70000,40000,45000,80000]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q7
#
# **Business Case:** Find monthly revenue.

# %%
import pandas as pd
df=pd.DataFrame({'order_date':['2025-01-01','2025-01-15','2025-02-01','2025-02-20','2025-03-01'],'amount':[100,300,500,200,700]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q8
#
# **Business Case:** Find customers who never placed an order.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,102,103,104],'name':['A','B','C','D']})
df1=pd.DataFrame({'order_id':[1,2],'customer_id':[101,103]})
print(df)
print(df1)

# %%
# Write your SQL here

# %% [markdown]
# ## Q9
#
# **Business Case:** Find the latest order for every customer.

# %%
import pandas as pd
df=pd.DataFrame({'order_id':[1,2,3,4,5],'customer_id':[101,101,102,102,103],'order_date':['2025-01-01','2025-02-01','2025-01-15','2025-03-01','2025-02-20'],'amount':[100,200,300,250,500]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q10
#
# **Business Case:** Find employees earning above their department average salary.

# %%
import pandas as pd
df=pd.DataFrame({'name':['A','B','C','D','E','F'],'department':['HR','HR','HR','IT','IT','IT'],'salary':[50000,60000,70000,40000,45000,80000]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q11
#
# **Business Case:** Find repeat customers (ordered on different dates).

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,103,103],'order_date':['2025-01-01','2025-02-01','2025-01-05','2025-01-10','2025-03-10']})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q12
#
# **Business Case:** Find category generating the highest revenue.

# %%
import pandas as pd
df=pd.DataFrame({'category':['A','A','B','B','C'],'amount':[100,300,500,400,900]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q13
#
# **Business Case:** Find customers whose first order was in January 2025.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,103],'order_date':['2025-01-01','2025-02-01','2025-01-15','2025-03-01']})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q14
#
# **Business Case:** Find top-selling product by total sales.

# %%
import pandas as pd
df=pd.DataFrame({'product_id':[1,1,2,2,3],'sales':[100,300,500,100,900]})
df

# %%
# Write your SQL here

# %% [markdown]
# ## Q15
#
# **Business Case:** Find customers who spent less than the average customer spending using a CTE.

# %%
import pandas as pd
df=pd.DataFrame({'customer_id':[101,101,102,103,104],'amount':[100,400,500,700,300]})
df

# %%
# Write your SQL here
